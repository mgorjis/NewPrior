# %%
# %load_ext autoreload
# %autoreload 2

# %%
import networkx as nx
import numpy as np

import copy
import random
import graphviz

from UtilsPrior2 import *

# %%
S=20
Lambda=3

# %%
Group=Grouping(S)
print(Group)
# Out:
# [[6, 8], [1, 14, 15], [9], [5, 10, 11], [2, 3, 4, 7, 17], [0, 12, 13, 16, 19], [18]]

# %%
Adj,Dtotal,CC=GenEdges(S,Group,Lambda)

print(Dtotal)    # the degree of each node

print('Number of connected components = ', CC)     # Number of connected components
# Out:
# [[1, 1], [1, 1, 2], [0], [2, 1, 1], [2, 3, 2, 2, 1], [1, 2, 2, 2, 3], [0]]
# Number of connected components =  7

# %%
participants=[str(i) for i in list(range(0,S))]
sketch(participants,Adj)

# %% [markdown]
# ## Calculate the Prior  , $\eta=0.5$

# %% [markdown]
# Prior= $P(C)^\eta .  \prod_{i=1}^S p(l_i|C,\lambda)^{1-\eta}  $

# %%
Calc_prior2(CC,Dtotal, Lambda)
# Out:
# 2.4305120990514542e-09
